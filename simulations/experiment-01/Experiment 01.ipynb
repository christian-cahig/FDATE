# %% [markdown]
# # Experiment 01

# %% [markdown]
# ## Core

# %%
import numpy, os, pickle, time
from matplotlib import pyplot
from utils import SimulationData, build_banded_matrix
# %matplotlib inline

# %%
# Initialize data
data = SimulationData(
    R=3e-3, L=1e-3, G=1e-2, C=1e3,
    X=1.0, T=1.0, num_x_points=100, num_t_points=1000,
    mu_0 = lambda x : numpy.sin(5*numpy.pi*x) + 2*numpy.sin(7*numpy.pi*x),
    xi_0 = 0.,
    nu_0 = lambda t : 0., nu_X = lambda t : 0.,
    name="experiment_01"
)
print(f"CFL number = {data.get_CFL_number()}\n")
# Out:
# Line parameters initialized.
# Domain parameters initialized.
# CFL number = 0.09909909909909909

# %%
# Experiment parameters
num_x_points = [int(100*i) for i in [1, 1.5, 2, 2.5, 3]]
num_t_points = [int(1000*i) for i in [1, 1.5, 2, 2.5, 3]]
num_runs = 20
runtimes = numpy.zeros((len(num_x_points),num_runs))
save_dir = "./"

# %% [markdown]
# ## Numerical solution: basic update scheme

# %%
# Run experiment
for i, (K_plus_1, N_plus_1) in enumerate(zip(num_x_points, num_t_points)):
    print(f">> Simulating with K = {K_plus_1-1} and N = {N_plus_1-1}")
    # Set data
    data.set_domain(num_x_points=K_plus_1, num_t_points=N_plus_1)
    print(f"  CFL number = {data.get_CFL_number()}")

    # Update scheme parameters
    A = 1. + 0.5 * data.domain["t step"] * (data.line["alpha"] + data.line["beta"])
    B = 1. - 0.5 * data.domain["t step"] * (data.line["alpha"] + data.line["beta"])
    E = data.line["c squared"] * data.domain["t step"]**2 / data.domain["x step"]**2
    F = 2. - (2. * data.line["c squared"] * data.domain["t step"]**2 / data.domain["x step"]**2) - (data.line["alpha"] * data.line["beta"] * data.domain["t step"]**2)

    # Get discretized domains
    x_domain = data.get_x_domain()
    t_domain = data.get_t_domain()
    
    for j in range(num_runs):
        print(f"Run no. {j+1}...", end="")
        
        # Initialize container for voltages
        u = numpy.zeros((data.domain["K"]+1, data.domain["N"]+1))
        
        # Start counter
        tic = time.perf_counter()
        
        # Initial conditions
        u[:,0] = data.init_condition_value(x_domain)
        u[0,0] = data.dirichlet_sending_end(t_domain[0])
        u[-1,0] = data.dirichlet_receiving_end(t_domain[0])
        u[:,1] = data.init_condition_deriv(u[:,0])
        u[0,1] = data.dirichlet_sending_end(t_domain[1])
        u[-1,1] = data.dirichlet_receiving_end(t_domain[1])

        # n=1,2,...,N-1
        for n in range(1,data.domain["N"]):
            # k=1,2,...,K-1
            for k in range(1,data.domain["K"]):
                u_was, u_now = u[k,n-1], u[k,n]
                u_now_left, u_now_right = u[k-1,n], u[k+1,n]
                u_nxt = E*u_now_left + F*u_now + E*u_now_right - B*u_was
                u_nxt /= A
                u[k,n+1] = u_nxt
            # k=0, K
            u[0,n+1] = data.dirichlet_sending_end(t_domain[n+1])
            u[-1,n+1] = data.dirichlet_receiving_end(t_domain[n+1])
        
        # Stop counter
        toc = time.perf_counter()
        
        # Record elapsed time
        runtimes[i,j] = toc-tic
        print(f"completed in {toc-tic} seconds.")

del A, B, E, F
del x_domain, t_domain
del i, K_plus_1, N_plus_1
del j, u, tic, toc
del n, k, u_was, u_now, u_now_left, u_now_right, u_nxt
# Out:
# >> Simulating with K = 99 and N = 999
# Domain parameters 'K' and 'x step' are adjusted.
# Domain parameters 'N' and 't step' are adjusted.
#   CFL number = 0.09909909909909909
# Run no. 1...completed in 0.20767310000000005 seconds.
# Run no. 2...completed in 0.19349029999999967 seconds.
# Run no. 3...completed in 0.1891058999999995 seconds.
# Run no. 4...completed in 0.19241229999999998 seconds.
# Run no. 5...completed in 0.21363339999999997 seconds.
# Run no. 6...completed in 0.20108939999999986 seconds.
# Run no. 7...completed in 0.2077928 seconds.
# Run no. 8...completed in 0.19214800000000043 seconds.
# Run no. 9...completed in 0.19944760000000006 seconds.
# Run no. 10...completed in 0.19800750000000011 seconds.
# Run no. 11...completed in 0.19644209999999962 seconds.
# Run no. 12...completed in 0.19631929999999986 seconds.
# Run no. 13...completed in 0.20176879999999997 seconds.
# Run no. 14...completed in 0.19967239999999986 seconds.
# Run no. 15...completed in 0.19435530000000067 seconds.
# Run no. 16...completed in 0.19697619999999993 seconds.
# Run no. 17...completed in 0.20490850000000016 seconds.
# Run no. 18...completed in 0.20294450000000008 seconds.
# Run no. 19...completed in 0.20196729999999974 seconds.
# Run no. 20...completed in 0.20205110000000115 seconds.
# >> Simulating with K = 149 and N = 1499
# Domain parameters 'K' and 'x step' are adjusted.
# Domain parameters 'N' and 't step' are adjusted.
#   CFL number = 0.09939959973315543
# Run no. 1...completed in 0.4383473000000002 seconds.
# Run no. 2...completed in 0.4415338000000002 seconds.
# Run no. 3...completed in 0.45264479999999985 seconds.
# Run no. 4...completed in 0.4625718999999986 seconds.
# Run no. 5...completed in 0.44002809999999926 seconds.
# Run no. 6...completed in 0.43177679999999974 seconds.
# Run no. 7...completed in 0.43304020000000065 seconds.
# Run no. 8...completed in 0.4498584999999995 seconds.
# Run no. 9...completed in 0.45277749999999983 seconds.
# Run no. 10...completed in 0.4419626999999995 seconds.
# Run no. 11...completed in 0.45232279999999925 seconds.
# Run no. 12...completed in 0.44613749999999897 seconds.
# Run no. 13...completed in 0.4412787999999992 seconds.
# Run no. 14...completed in 0.4341000000000008 seconds.
# Run no. 15...completed in 0.43985829999999915 seconds.
# Run no. 16...completed in 0.44201070000000087 seconds.
# Run no. 17...completed in 0.4364498000000001 seconds.
# Run no. 18...completed in 0.442606099999999 seconds.
# Run no. 19...completed in 0.44617330000000166 seconds.
# Run no. 20...completed in 0.45207599999999815 seconds.
# >> Simulating with K = 199 and N = 1999
# Domain parameters 'K' and 'x step' are adjusted.
# Domain parameters 'N' and 't step' are adjusted.
#   CFL number = 0.09954977488744371
# Run no. 1...completed in 0.8217642999999981 seconds.
# Run no. 2...completed in 0.7938742999999988 seconds.
# Run no. 3...completed in 0.7860179000000009 seconds.
# Run no. 4...completed in 0.8054196000000005 seconds.
# Run no. 5...completed in 0.8191012999999998 seconds.
# Run no. 6...completed in 0.8360169999999982 seconds.
# Run no. 7...completed in 0.8518510000000035 seconds.
# Run no. 8...completed in 0.8731055999999988 seconds.
# Run no. 9...completed in 0.8585884000000021 seconds.
# Run no. 10...completed in 0.8595116000000012 seconds.
# Run no. 11...completed in 0.8379308999999999 seconds.
# Run no. 12...completed in 0.8329632000000018 seconds.
# Run no. 13...completed in 0.7822133000000022 seconds.
# Run no. 14...completed in 0.8405493999999969 seconds.
# Run no. 15...completed in 0.8360842999999996 seconds.
# Run no. 16...completed in 0.8514037999999999 seconds.
# Run no. 17...completed in 0.8386502 seconds.
# Run no. 18...completed in 0.8164204999999995 seconds.
# Run no. 19...completed in 0.8244177999999991 seconds.
# Run no. 20...completed in 0.8344956000000039 seconds.
# >> Simulating with K = 249 and N = 2499
# Domain parameters 'K' and 'x step' are adjusted.
# Domain parameters 'N' and 't step' are adjusted.
#   CFL number = 0.09963985594237697
# Run no. 1...completed in 1.2602916000000022 seconds.
# Run no. 2...completed in 1.2287555999999995 seconds.
# Run no. 3...completed in 1.243715299999998 seconds.
# Run no. 4...completed in 1.2568835000000007 seconds.
# Run no. 5...completed in 1.2757259999999988 seconds.
# Run no. 6...completed in 1.2480218999999977 seconds.
# Run no. 7...completed in 1.2249701000000002 seconds.
# Run no. 8...completed in 1.2876896000000002 seconds.
# Run no. 9...completed in 1.2338452999999987 seconds.
# Run no. 10...completed in 1.2745219999999975 seconds.
# Run no. 11...completed in 1.2439684 seconds.
# Run no. 12...completed in 1.281725999999999 seconds.
# Run no. 13...completed in 1.2364549999999994 seconds.
# Run no. 14...completed in 1.2329079000000007 seconds.
# Run no. 15...completed in 1.246353599999999 seconds.
# Run no. 16...completed in 1.2442150999999981 seconds.
# Run no. 17...completed in 1.3079869999999971 seconds.
# Run no. 18...completed in 1.2799292999999992 seconds.
# Run no. 19...completed in 1.3384566000000007 seconds.
# Run no. 20...completed in 1.2220675999999955 seconds.
# >> Simulating with K = 299 and N = 2999
# Domain parameters 'K' and 'x step' are adjusted.
# Domain parameters 'N' and 't step' are adjusted.
#   CFL number = 0.09969989996665554
# Run no. 1...completed in 1.9038162000000014 seconds.
# Run no. 2...completed in 1.9246073999999993 seconds.
# Run no. 3...completed in 1.8650342999999978 seconds.
# Run no. 4...completed in 1.9216465999999883 seconds.
# Run no. 5...completed in 1.810680199999993 seconds.
# Run no. 6...completed in 1.7991291000000018 seconds.
# Run no. 7...completed in 1.8116224000000045 seconds.
# Run no. 8...completed in 1.7978846999999973 seconds.
# Run no. 9...completed in 1.8454889000000065 seconds.
# Run no. 10...completed in 1.8246316000000036 seconds.
# Run no. 11...completed in 1.8657634000000058 seconds.
# Run no. 12...completed in 1.8151967999999954 seconds.
# Run no. 13...completed in 1.8385736000000037 seconds.
# Run no. 14...completed in 1.9273078999999882 seconds.
# Run no. 15...completed in 1.7960311000000075 seconds.
# Run no. 16...completed in 1.9042618000000004 seconds.
# Run no. 17...completed in 1.8091672000000045 seconds.
# Run no. 18...completed in 1.783746899999997 seconds.
# Run no. 19...completed in 1.8471013999999997 seconds.
# Run no. 20...completed in 1.8774808999999948 seconds.

# %%
# Save results
with open(os.path.join(save_dir, "basic-update-scheme.pkl"), 'wb') as file:
        pickle.dump(runtimes, file)
print("Runtime results saved to " + os.path.join(save_dir, "basic-update-scheme.pkl") + ".")
del file
# Out:
# Runtime results saved to ./basic-update-scheme.pkl.

# %% [markdown]
# ## Numerical solution: vectorized update scheme

# %%
# Run experiment
for i, (K_plus_1, N_plus_1) in enumerate(zip(num_x_points, num_t_points)):
    print(f">> Simulating with K = {K_plus_1-1} and N = {N_plus_1-1}")
    # Set data
    data.set_domain(num_x_points=K_plus_1, num_t_points=N_plus_1)
    print(f"  CFL number = {data.get_CFL_number()}")

    # Update scheme parameters
    A = 1. + 0.5 * data.domain["t step"] * (data.line["alpha"] + data.line["beta"])
    B = 1. - 0.5 * data.domain["t step"] * (data.line["alpha"] + data.line["beta"])
    E = data.line["c squared"] * data.domain["t step"]**2 / data.domain["x step"]**2
    F = 2. - (2. * data.line["c squared"] * data.domain["t step"]**2 / data.domain["x step"]**2) - (data.line["alpha"] * data.line["beta"] * data.domain["t step"]**2)
    E_matrix = build_banded_matrix(numpy.array([E, F, E]), data.domain["K"]-1)
    B_matrix = B*numpy.concatenate(
        (numpy.zeros((data.domain["K"]-1,1)), numpy.identity(data.domain["K"]-1), numpy.zeros((data.domain["K"]-1,1))),
        axis=1
    )

    # Get discretized domains
    x_domain = data.get_x_domain()
    t_domain = data.get_t_domain()
    
    for j in range(num_runs):
        print(f"Run no. {j+1}...", end="")
        
        # Initialize container for voltages
        u = numpy.zeros((data.domain["K"]+1, data.domain["N"]+1))
        
        # Start counter
        tic = time.perf_counter()
        
        # Initial conditions
        u[:,0] = data.init_condition_value(x_domain)
        u[0,0] = data.dirichlet_sending_end(t_domain[0])
        u[-1,0] = data.dirichlet_receiving_end(t_domain[0])
        u[:,1] = data.init_condition_deriv(u[:,0])
        u[0,1] = data.dirichlet_sending_end(t_domain[1])
        u[-1,1] = data.dirichlet_receiving_end(t_domain[1])

        # n=1,2,...,N-1
        for n in range(1,data.domain["N"]):
            u_was, u_now = u[:,n-1], u[:,n]
            # k=1,2,...,K-1
            hat_u_nxt = numpy.dot(E_matrix, u_now) - numpy.dot(B_matrix, u_was)
            hat_u_nxt /= A
            # k=0,1,...,K
            u_nxt = numpy.concatenate(
                (numpy.array([data.dirichlet_sending_end(t_domain[n+1])]),
                 hat_u_nxt,
                 numpy.array([data.dirichlet_receiving_end(t_domain[n+1])]))
            )
            u[:,n+1] = u_nxt
        
        # Stop counter
        toc = time.perf_counter()
        
        # Record elapsed time
        runtimes[i,j] = toc-tic
        print(f"completed in {toc-tic} seconds.")

del A, B, E, F, E_matrix, B_matrix
del x_domain, t_domain
del i, K_plus_1, N_plus_1
del j, u, tic, toc
del n, u_was, u_now, hat_u_nxt, u_nxt
# Out:
# >> Simulating with K = 99 and N = 999
# Domain parameters 'K' and 'x step' are adjusted.
# Domain parameters 'N' and 't step' are adjusted.
#   CFL number = 0.09909909909909909
# Run no. 1...completed in 0.1059126999999993 seconds.
# Run no. 2...completed in 0.09514620000000029 seconds.
# Run no. 3...completed in 0.09631420000000013 seconds.
# Run no. 4...completed in 0.09497089999999986 seconds.
# Run no. 5...completed in 0.09650910000000046 seconds.
# Run no. 6...completed in 0.09693170000000073 seconds.
# Run no. 7...completed in 0.09905770000000125 seconds.
# Run no. 8...completed in 0.09845939999999942 seconds.
# Run no. 9...completed in 0.09717120000000001 seconds.
# Run no. 10...completed in 0.09664810000000124 seconds.
# Run no. 11...completed in 0.09717080000000067 seconds.
# Run no. 12...completed in 0.09626360000000034 seconds.
# Run no. 13...completed in 0.09815190000000129 seconds.
# Run no. 14...completed in 0.09751239999999939 seconds.
# Run no. 15...completed in 0.09728660000000033 seconds.
# Run no. 16...completed in 0.0966509000000002 seconds.
# Run no. 17...completed in 0.09744299999999839 seconds.
# Run no. 18...completed in 0.09803309999999854 seconds.
# Run no. 19...completed in 0.09820309999999921 seconds.
# Run no. 20...completed in 0.09771919999999668 seconds.
# >> Simulating with K = 149 and N = 1499
# Domain parameters 'K' and 'x step' are adjusted.
# Domain parameters 'N' and 't step' are adjusted.
#   CFL number = 0.09939959973315543
# Run no. 1...completed in 0.15570229999999796 seconds.
# Run no. 2...completed in 0.15530190000000132 seconds.
# Run no. 3...completed in 0.15409769999999767 seconds.
# Run no. 4...completed in 0.15735100000000202 seconds.
# Run no. 5...completed in 0.1549168999999999 seconds.
# Run no. 6...completed in 0.15838929999999962 seconds.
# Run no. 7...completed in 0.15697010000000233 seconds.
# Run no. 8...completed in 0.15512430000000066 seconds.
# Run no. 9...completed in 0.15391969999999944 seconds.
# Run no. 10...completed in 0.15480610000000183 seconds.
# Run no. 11...completed in 0.15524429999999967 seconds.
# Run no. 12...completed in 0.15572470000000038 seconds.
# Run no. 13...completed in 0.1566855000000018 seconds.
# Run no. 14...completed in 0.15726099999999832 seconds.
# Run no. 15...completed in 0.1568050999999997 seconds.
# Run no. 16...completed in 0.15634890000000112 seconds.
# Run no. 17...completed in 0.15709679999999793 seconds.
# Run no. 18...completed in 0.15629699999999858 seconds.
# Run no. 19...completed in 0.15687929999999994 seconds.
# Run no. 20...completed in 0.16186109999999942 seconds.
# >> Simulating with K = 199 and N = 1999
# Domain parameters 'K' and 'x step' are adjusted.
# Domain parameters 'N' and 't step' are adjusted.
#   CFL number = 0.09954977488744371
# Run no. 1...completed in 0.25696080000000165 seconds.
# Run no. 2...completed in 0.23128460000000217 seconds.
# Run no. 3...completed in 0.23808859999999754 seconds.
# Run no. 4...completed in 0.2417107999999999 seconds.
# Run no. 5...completed in 0.21526159999999805 seconds.
# Run no. 6...completed in 0.22991710000000154 seconds.
# Run no. 7...completed in 0.2555854999999987 seconds.
# Run no. 8...completed in 0.22433240000000154 seconds.
# Run no. 9...completed in 0.22496519999999975 seconds.
# Run no. 10...completed in 0.22660039999999881 seconds.
# Run no. 11...completed in 0.22782980000000208 seconds.
# Run no. 12...completed in 0.22509349999999984 seconds.
# Run no. 13...completed in 0.2218808999999986 seconds.
# Run no. 14...completed in 0.23910899999999913 seconds.
# Run no. 15...completed in 0.24341700000000088 seconds.
# Run no. 16...completed in 0.2371106999999988 seconds.
# Run no. 17...completed in 0.24458500000000072 seconds.
# Run no. 18...completed in 0.24211939999999998 seconds.
# Run no. 19...completed in 0.24096169999999972 seconds.
# Run no. 20...completed in 0.23553400000000124 seconds.
# >> Simulating with K = 249 and N = 2499
# Domain parameters 'K' and 'x step' are adjusted.
# Domain parameters 'N' and 't step' are adjusted.
#   CFL number = 0.09963985594237697
# Run no. 1...completed in 0.30910889999999824 seconds.
# Run no. 2...completed in 0.3075946000000016 seconds.
# Run no. 3...completed in 0.33448239999999885 seconds.
# Run no. 4...completed in 0.3132736999999999 seconds.
# Run no. 5...completed in 0.31488530000000026 seconds.
# Run no. 6...completed in 0.3207751000000023 seconds.
# Run no. 7...completed in 0.3115111000000006 seconds.
# Run no. 8...completed in 0.3098056000000007 seconds.
# Run no. 9...completed in 0.3050514 seconds.
# Run no. 10...completed in 0.3217253999999983 seconds.
# Run no. 11...completed in 0.3073547999999988 seconds.
# Run no. 12...completed in 0.309337799999998 seconds.
# Run no. 13...completed in 0.3100296 seconds.
# Run no. 14...completed in 0.30719660000000104 seconds.
# Run no. 15...completed in 0.3091500000000025 seconds.
# Run no. 16...completed in 0.30792479999999856 seconds.
# Run no. 17...completed in 0.3057643999999975 seconds.
# Run no. 18...completed in 0.3065437000000024 seconds.
# Run no. 19...completed in 0.30610030000000066 seconds.
# Run no. 20...completed in 0.3342092000000001 seconds.
# >> Simulating with K = 299 and N = 2999
# Domain parameters 'K' and 'x step' are adjusted.
# Domain parameters 'N' and 't step' are adjusted.
#   CFL number = 0.09969989996665554
# Run no. 1...completed in 0.44537329999999997 seconds.
# Run no. 2...completed in 0.44912959999999913 seconds.
# Run no. 3...completed in 0.4129266999999963 seconds.
# Run no. 4...completed in 0.3951952999999975 seconds.
# Run no. 5...completed in 0.3901497999999961 seconds.
# Run no. 6...completed in 0.39161949999999734 seconds.
# Run no. 7...completed in 0.3990581999999989 seconds.
# Run no. 8...completed in 0.40147110000000197 seconds.
# Run no. 9...completed in 0.39610389999999995 seconds.
# Run no. 10...completed in 0.39914170000000126 seconds.
# Run no. 11...completed in 0.39743339999999705 seconds.
# Run no. 12...completed in 0.39424009999999754 seconds.
# Run no. 13...completed in 0.3916394999999966 seconds.
# Run no. 14...completed in 0.3973614000000012 seconds.
# Run no. 15...completed in 0.4043019000000001 seconds.
# Run no. 16...completed in 0.4241547999999966 seconds.
# Run no. 17...completed in 0.4204048 seconds.
# Run no. 18...completed in 0.42871010000000354 seconds.
# Run no. 19...completed in 0.3993222000000003 seconds.
# Run no. 20...completed in 0.400020099999999 seconds.

# %%
# Save results
with open(os.path.join(save_dir, "vectorized-update-scheme.pkl"), 'wb') as file:
        pickle.dump(runtimes, file)
print("Runtime results saved to " + os.path.join(save_dir, "vectorized-update-scheme.pkl") + ".")
del file
# Out:
# Runtime results saved to ./vectorized-update-scheme.pkl.

# %% [markdown]
# ## Results summary
